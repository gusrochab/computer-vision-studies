# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('images/exame1-1.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (665, 610, 3)

# %%
plt.imshow(img)

# %%
# Matplotlib -> RGB
#OpenCV      -> BGR

# %%
fixed_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_img)

# %%
img_gray = cv2.imread('images/exame1-1.png', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (665, 610)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
resized_img = cv2.resize(fixed_img, (1000, 1000))

# %%
plt.imshow(resized_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
resized_ratio_img = cv2.resize(fixed_img, (0,0), fixed_img, w_ratio, h_ratio)

# %%
plt.imshow(resized_ratio_img)

# %%
fliped_img = cv2.flip(fixed_img, 0)

# %%
plt.imshow(fliped_img)

# %%
type(fixed_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('new_exam1.jpg', fixed_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fixed_img)

# %% [markdown]
# ### RESUME

# %%
cv2.imwrite('name', img)
cv2.resize(img, (500,500), img, w_ratio, h_ratio)
cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.imread('name', cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
